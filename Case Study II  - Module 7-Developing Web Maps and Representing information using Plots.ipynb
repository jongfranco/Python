# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium as mp
from folium import plugins

# %%
crime = pd.read_csv('Police_Department_Incidents_Year_2016_.csv')

# %% [markdown]
# # 1. Display first 100 records from the data and play with parameters - tiles, zoom_start etc. Map will be saved in BasicWebMap.html – view it in browser

# %%
crime100 = crime.head(100)

# %%
crime100.dtypes
# Out:
# IncidntNum      int64
# Category       object
# Descript       object
# DayOfWeek      object
# Date           object
# Time           object
# PdDistrict     object
# Resolution     object
# Address        object
# X             float64
# Y             float64
# Location       object
# PdId            int64
# dtype: object

# %%
crime100.isnull().sum()
# Out:
# IncidntNum    0
# Category      0
# Descript      0
# DayOfWeek     0
# Date          0
# Time          0
# PdDistrict    0
# Resolution    0
# Address       0
# X             0
# Y             0
# Location      0
# PdId          0
# dtype: int64

# %%
lon = list(crime100['X'])
lat = list(crime100['Y'])
print(lon)
print(lat)
#evel = list(df['ELEV'])
# Out:
# [-122.40340479147905, -122.40340479147905, -122.4154323065427, -122.38885620429184, -122.43995406172891, -122.44661297883863, -122.4154323065427, -122.4087076339152, -122.41967178029562, -122.40572145456717, -122.41177829599216, -122.4154323065427, -122.41405629189116, -122.3871816359951, -122.44188411610992, -122.38951764803555, -122.41875384815205, -122.44709993644042, -122.43232587102835, -122.40090869889043, -122.40859511086857, -122.40687040208216, -122.42035478086113, -122.43990976677156, -122.40842111692216, -122.4223156707488, -122.4154323065427, -122.43195768519577, -122.40328484310558, -122.4124243640024, -122.41767292362611, -122.49346849500573, -122.43033278747184, -122.45262934380669, -122.39738894783345, -122.40697756369153, -122.40340479147905, -122.4143020525436, -122.40340479147905, -122.41250614556007, -122.40834414753105, -122.43638322274604, -122.41356409174415, -122.4254162900708, -122.475287886078, -122.40212081575842, -122.41844818610123, -122.4310463660887, -1
# ...

# %%
map1 = mp.Map(location=[37.775421,-122.403405],zoom_start=12,tiles='stamenterrain')

# %%
fgv = mp.FeatureGroup(name="Crime Incidents")

for lt,ln in zip(lat,lon):
    fgv.add_child(mp.Marker(location=[lt,ln],popup="Crime",icon=mp.Icon(color = "red",icon='angry')))#popup=str(el)+" m",icon=mp.Icon(color=getcolor(el)))
map1.add_child(fgv)
map1.add_child(mp.LayerControl())
map1
map1.save("BasicWebMap.html ")

# %% [markdown]
# # 2. For latest 7 days of data create WebMap of Crimes which are categorized as ROBBERY

# %%
crime1 = crime[crime['Category']=='ROBBERY']
#crime1.head()

# %%
crime1.sort_values(by=['Date'],ascending=False)
new = crime1['Date'].str.split(" ",n=1,expand=True)
#data["Name"].str.split(" ", n = 1, expand = True) 
crime1['MDY']=new[0]
crime1.dtypes
crime1.sort_values(by=['MDY'],ascending=False)
crime1['MDY'] = pd.to_datetime(crime1['MDY'])
crime1.dtypes
lastdayfrom = pd.to_datetime('12/31/2016')
lastdayfrom
df = crime1.set_index('MDY')
df= df.sort_index()
df = df.loc[lastdayfrom - pd.Timedelta(days=6):lastdayfrom].reset_index()
df['MDY'].unique()
lon1 = list(df['X'])
lat1 = list(df['Y'])
print(lon1)
print(lat1)
#evel = list(df['ELEV'])

Rmap = mp.Map(location=[37.775421,-122.403405],zoom_start=12,tiles='stamenterrain')
fgv = mp.FeatureGroup(name="Robbery Crime Incidents")

for lt1,ln1 in zip(lat,lon):
    fgv.add_child(mp.Marker(location=[lt1,ln1],popup="Robbery Crime",icon=mp.Icon(color = "red",icon='angry')))#popup=str(el)+" m",icon=mp.Icon(color=getcolor(el)))
Rmap.add_child(fgv)
Rmap.add_child(mp.LayerControl())
Rmap
Rmap.save("RobberyMap.html ")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# ...

# %% [markdown]
# # 3. For latest 15 days of data create One WebMap of Crimes which are categorized as FRAUD and GAMBLING. Change the icon to font awesome icon (http://fontawesome.io/icons/)

# %%
# Fcrime = crime[(crime['Category']=='GAMBLING')]# | (crime['Category']=='GAMBLING')]'FRAUD' OR 
# len(Fcrime)

# %%
Fcrime1 = crime[(crime['Category']=='FRAUD')|(crime['Category']=='GAMBLING')]
#Fcrime1.to_csv('FandG.csv')
Fcrime1.sort_values(by=['Date'],ascending=False)
# Out:
#         IncidntNum Category  \
# 15268    170007075    FRAUD
# 144604   170006685    FRAUD
# 21519    170084039    FRAUD
# 83306    161062428    FRAUD
# 83418    161063216    FRAUD
# 144760   170015608    FRAUD
# 144468   170068083    FRAUD
# 47234    161063103    FRAUD
# 127469   170323655    FRAUD
# 68203    161061997    FRAUD
# 11464    161060739    FRAUD
# 131505   161062280    FRAUD
# 105966   161061107    FRAUD
# 44477    161059124    FRAUD
# 149405   170377367    FRAUD
# 112815   170029308    FRAUD
# 82574    161057689    FRAUD
# 82449    161056142    FRAUD
# 138250   161054259    FRAUD
# 131355   161054146    FRAUD
# 108355   161054099    FRAUD
# 68219    161062412    FRAUD
# 82208    161054663    FRAUD
# 136077   170014951    FRAUD
# 146502   170272563    FRAUD
# 43859    161055962    FRAUD
# 43102    161051114    FRAUD
# 131380   161054550    FRAUD
# 82871    161060018    FRAUD
# 132754   170039181    FRAUD
# ...            ...      ...
# 39992    160009865    FRAUD
# ...

# %%
new1 = Fcrime1['Date'].str.split(" ",n=1,expand=True)
#data["Name"].str.split(" ", n = 1, expand = True) 
Fcrime1['MDY']=new1[0]
#Fcrime1.dtypes
Fcrime1.sort_values(by=['MDY'],ascending=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         IncidntNum Category  \
# 15268    170007075    FRAUD
# 144604   170006685    FRAUD
# 21519    170084039    FRAUD
# 83306    161062428    FRAUD
# 83418    161063216    FRAUD
# 144760   170015608    FRAUD
# 144468   170068083    FRAUD
# 47234    161063103    FRAUD
# 127469   170323655    FRAUD
# 68203    161061997    FRAUD
# 11464    161060739    FRAUD
# 131505   161062280    FRAUD
# 105966   161061107    FRAUD
# 44477    161059124    FRAUD
# 149405   170377367    FRAUD
# 112815   170029308    FRAUD
# 82574    161057689    FRAUD
# ...

# %%
Fcrime1['MDY'] = pd.to_datetime(Fcrime1['MDY'])
Fcrime1.dtypes
lastdayfrom1 = pd.to_datetime('12/31/2016')
lastdayfrom1
df1 = Fcrime1.set_index('MDY')
df1= df1.sort_index()
df1 = df1.loc[lastdayfrom1 - pd.Timedelta(days=6):lastdayfrom1].reset_index()
df1['MDY'].unique()
lon2 = list(df1['X'])
lat2 = list(df1['Y'])
print(lat2)
print(lon2)
#evel = list(df['ELEV'])

Rmap1 = mp.Map(location=[37.711166,-122.449529],zoom_start=13,tiles='stamenterrain')
#Rmap1
fgv1 = mp.FeatureGroup(name="Fraud and Gambling Crime Incidents")

for lt2,ln2 in zip(lat2,lon2):
    fgv1.add_child(mp.Marker(location=[lt2,ln2],popup="Fraud and Gambling Crime",icon=mp.Icon(color = "red",icon='angry')))#popup=str(el)+" m",icon=mp.Icon(color=getcolor(el)))
Rmap1.add_child(fgv1)
Rmap1.add_child(mp.LayerControl())
#Rmap1
Rmap1.save("Fraud and GamblingMap.html ")
# Out:
# [37.78418470913026, 37.76050007259954, 37.77246824000607, 37.78331040670147, 37.799470444403994, 37.78604322229923, 37.79188233555996, 37.78792690045113, 37.78604322229923, 37.785062942166064, 37.77595124427489, 37.76844015856147, 37.78662723254503, 37.785062942166064, 37.76422056037451, 37.785785061938206, 37.776764029771215, 37.79368360077286, 37.767462526182506, 37.77480877654653, 37.78792093755329, 37.72411745184828, 37.78125509354836, 37.769215670589396, 37.70960320411078, 37.716636765558974, 37.80826133054392, 37.78043733189962, 37.74213368194098, 37.78735949495599, 37.7826462926371, 37.78689969776589, 37.77514629165388, 37.7441460741742, 37.77133828044993, 37.78083877913966, 37.782821449013966, 37.78302957160442, 37.732214427203324, 37.73072152157033, 37.78331040670147, 37.72202452302475, 37.771196203237636, 37.755343095442036, 37.72807545690939, 37.797946673298284, 37.71331778444795, 37.711166017359545, 37.77594528246741]
# ...

# %% [markdown]
# # 4. BONUS ASSIGNMENT -- Display heatmap for Divvy Bikes. Divvy Bikes runs bike rental service in Chicago and their bike station geolocation data is shared. Refer to BikesHeatMap.py and Divvy_Stations_2016_Q3.csv, Divvy_Stations_2016_Q4.csv

# %%
divvyStations_q3 = pd.read_csv('Divvy_Stations_2016_Q3.csv')
divvyStations_q4 = pd.read_csv('Divvy_Stations_2016_Q4.csv')

# combine and keep the first instance of id
divvyStations = pd.concat([divvyStations_q3, divvyStations_q4], axis=0).drop_duplicates(subset=['id'])
print(divvyStations.head())

CHICAGO_COORD = [41.8781, -87.6298]

map_heat = mp.Map(CHICAGO_COORD,zoom_start=11)

# mark each station as a point
# Uncomment the code below and check

# for index, row in divvyStations.iterrows():
#     folium.CircleMarker([row['latitude'], row['longitude']],
#                         radius=15,
#                         popup=row['name'],
#                         fill_color="#3db7e4",  # divvy color
#                         ).add_to(map_heat)


stationArr = [[row['latitude'],row['longitude']] for index, row in divvyStations.iterrows()]


# plot heatmap
map_heat.add_child(plugins.HeatMap(stationArr, radius=15))
map_heat.save("BikeStationHeatMap.html")
print(map_heat)
# Out:
#     id                        name   latitude  longitude  dpcapacity  \
# 0  456         2112 W Peterson Ave  41.991178 -87.683593          15
# 1  101               63rd St Beach  41.781016 -87.576120          23
# 2  109           900 W Harrison St  41.874675 -87.650019          19
# 3   21  Aberdeen St & Jackson Blvd  41.877726 -87.654787          15
# 4   80     Aberdeen St & Monroe St  41.880420 -87.655599          19
#
#   online_date
# 0   5/12/2015
# 1   4/20/2015
# 2    8/6/2013
# 3   6/21/2013
# 4   6/26/2013
# ...

# %% [markdown]
# # Enhancements for code

# %%
# You can try these enhancements in code
# 1. Lot of visual options are available to change the map. You can refer to
# https://python-visualization.github.io/folium/modules.html for options

# %% [markdown]
# # 2. Change the code to create webmap for 'BURGALRY ' for last 7 days

# %%
crime1 = crime[crime['Category']=='ROBBERY']
#crime1.head()
crime1.sort_values(by=['Date'],ascending=False)
new = crime1['Date'].str.split(" ",n=1,expand=True)
#data["Name"].str.split(" ", n = 1, expand = True) 
crime1['MDY']=new[0]
crime1.dtypes
crime1.sort_values(by=['MDY'],ascending=False)
crime1['MDY'] = pd.to_datetime(crime1['MDY'])
crime1.dtypes
lastdayfrom = pd.to_datetime('12/31/2016')
lastdayfrom
df = crime1.set_index('MDY')
df= df.sort_index()
df = df.loc[lastdayfrom - pd.Timedelta(days=6):lastdayfrom].reset_index()
df['MDY'].unique()
lon1 = list(df['X'])
lat1 = list(df['Y'])
print(lon1)
print(lat1)
#evel = list(df['ELEV'])

Rmap = mp.Map(location=[37.775421,-122.403405],zoom_start=12,tiles='Mapbox Bright')
fgv = mp.FeatureGroup(name="Robbery Crime Incidents")

for lt1,ln1 in zip(lat,lon):
    fgv.add_child(mp.Marker(location=[lt1,ln1],popup="Robbery Crime",icon=mp.Icon(color = "red",icon='angry')))#popup=str(el)+" m",icon=mp.Icon(color=getcolor(el)))
Rmap.add_child(fgv)
Rmap.add_child(mp.LayerControl())
Rmap
Rmap.save("RobberyMap.html ")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ...

# %% [markdown]
# # 3. BONUS ASSIGNMENT – Uncomment the code see the changes

# %%
divvyStations_q3 = pd.read_csv('Divvy_Stations_2016_Q3.csv')
divvyStations_q4 = pd.read_csv('Divvy_Stations_2016_Q4.csv')

# combine and keep the first instance of id
divvyStations = pd.concat([divvyStations_q3, divvyStations_q4], axis=0).drop_duplicates(subset=['id'])
print(divvyStations.head())

CHICAGO_COORD = [41.8781, -87.6298]

map_heat = mp.Map(CHICAGO_COORD,zoom_start=11)

# mark each station as a point
# Uncomment the code below and check

for index, row in divvyStations.iterrows():
    mp.CircleMarker([row['latitude'], row['longitude']],radius=15,popup=row['name'],fill_color="#3db7e4").add_to(map_heat)  # divvy color


stationArr = [[row['latitude'],row['longitude']] for index, row in divvyStations.iterrows()]


# plot heatmap
map_heat.add_child(plugins.HeatMap(stationArr, radius=15))
map_heat.save("BikeStationHeatMap.html")
map_heat
# Out:
#     id                        name   latitude  longitude  dpcapacity  \
# 0  456         2112 W Peterson Ave  41.991178 -87.683593          15
# 1  101               63rd St Beach  41.781016 -87.576120          23
# 2  109           900 W Harrison St  41.874675 -87.650019          19
# 3   21  Aberdeen St & Jackson Blvd  41.877726 -87.654787          15
# 4   80     Aberdeen St & Monroe St  41.880420 -87.655599          19
#
#   online_date
# 0   5/12/2015
# 1   4/20/2015
# 2    8/6/2013
# 3   6/21/2013
# 4   6/26/2013
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
