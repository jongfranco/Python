# %%
pip install folium
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install folium
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
import folium as mp

# %%
dmp = mp.Map(location = [48.553404,2.950537],zoom_start=10,tiles='stamenterrain')#stamenwatercolor/Mapbox Bright/stamenterrain/OpenStreetMap/Mapbox Control Room
#dmp.save("folium.html")
dmp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
vol = mp.FeatureGroup(name = 'Volcaneos')

# %%
map = mp.Map(location=[12.2,75.1],zoom_start=6,tiles="Mapbox Bright")

schools = mp.FeatureGroup(name="Schools")
for coordinate in ([12.958016,77.744033],[13.958016,76.744033],[10.958016,74.744033]):
    schools.add_child(mp.Marker(location=coordinate,popup="Schools Info",icon=mp.Icon(color = "red",icon='cloud')))
map.add_child(schools)
map

Hotels = mp.FeatureGroup(name="Hotels")
for coordinate1 in ([11.958016,77.744033],[17.958016,76.744033],[10.958016,72.744033]):
    Hotels.add_child(mp.Marker(location=coordinate1,popup="Hotel Info",icon=mp.Icon(color = "yellow")))
map.add_child(Hotels)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import os

# %%
os.chdir("C://Users//G705961//Downloads//Python")

# %%
df = pd.read_csv("Volcanoes_USA.txt")

# %%
df.head()
# Out:
#    VOLCANX020    NUMBER          NAME       LOCATION            STATUS  \
# 0       509.0  1201-01=         Baker  US-Washington        Historical
# 1       511.0  1201-02-  Glacier Peak  US-Washington  Tephrochronology
# 2       513.0  1201-03-       Rainier  US-Washington  Dendrochronology
# 3       515.0  1201-05-    St. Helens  US-Washington        Historical
# 4       516.0  1201-04-         Adams  US-Washington  Tephrochronology
#
#      ELEV             TYPE TIMEFRAME        LAT         LON
# 0  3285.0  Stratovolcanoes        D3  48.776798 -121.810997
# 1  3213.0    Stratovolcano        D4  48.111801 -121.111000
# 2  4392.0    Stratovolcano        D3  46.869801 -121.751000
# 3  2549.0    Stratovolcano        D1  46.199799 -122.181000
# 4  3742.0    Stratovolcano        D6  46.205799 -121.490997

# %%
df1 = df[['NAME','ELEV','LAT','LON']]

# %%
lon = list(df['LON'])
lat = list(df['LAT'])
evel = list(df['ELEV'])

# %%
print(lon)
print(lat)
print(evel)
# Out:
# [-121.810997, -121.1110001, -121.7509995, -122.1809998, -121.4909973, -122.0810013, -121.8209991, -121.6910019, -121.8010025, -121.7710037, -121.9309998, -121.8310013, -121.8410034, -121.7710037, -121.7710037, -121.6809998, -121.2210007, -121.8209991, -120.8610001, -122.10099790000001, -120.7509995, -120.6610031, -122.1210022, -110.6709976, -118.7509995, -117.4710007, -117.8010025, -113.5009995, -112.45099640000001, -114.35099790000001, -117.5810013, -121.5709991, -113.2210007, -122.20099640000001, -121.4410019, -121.3610001, -121.60099790000001, -121.5510025, -120.8310013, -121.5009995, -122.7710037, -119.7210007, -107.03099820000001, -119.03099820000001, -112.5009995, -119.0009995, -119.0210037, -118.8710022, -119.0510025, -117.45099640000001, -112.6709976, -113.6210022, -112.40100100000001, -118.3209991, -117.8209991, -113.1309967, -116.6210022, -106.5709991, -111.5009995, -115.78099820000001, -108.0009995, -105.9309998]
# ...

# %%
def getcolor(elevation):
    if elevation<1000:
        return('red')
    elif elevation<=3000:
        return('blue')
    else:
        return('black')

# %%
for x in evel:
    getcolor(x)

# %%
map1 = mp.Map(location=[48.111801,-121.111000],zoom_start=3,tiles='stamenterrain')

# %%
fgv = mp.FeatureGroup(name="Volcanoes")

for lt,ln,el in zip(lat,lon,evel):
    fgv.add_child(mp.Marker(location=[lt,ln],popup=str(el)+" m",icon=mp.Icon(color=getcolor(el))))
map1.add_child(fgv)
map1.add_child(mp.LayerControl())
map1
#map1.save("f.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
